# %%
from slippi import Game
from slippi.parse import parse
from slippi.parse import ParseEvent
import pandas as pd
from os import listdir
from os.path import isfile, join
import tqdm

# %%
def parse_frame_at_port(game, frame, port):
    return [port, frame+1, game.frames[frame].ports[port].leader.pre, game.frames[frame].ports[port].leader.post]

# %%
def read_game(file_name):
    try:
        return Game(f'../Data/{file_name}')
    except:
        print(f'Failed to parse {file_name}')

# %%
def add_replay(file_name, d, k):
    game = read_game(file_name)
    if game is None:
            print(f'{file_name} is None')
    else: 
        for i in range(len(game.start.players)):
            pl = game.start.players[i]
            if not(pl is None):
                char = pl.character.name
                head = [file_name, char]
                for f in range(len(game.frames)):
                    d[k] = head + parse_frame_at_port(game, f, i)
                    k += 1
    return d, k

# %%
def replays_to_df(replay_names):
    data = dict()
    k = 0
    for replay in replay_names:
        data, k = add_replay(replay, data, k)
    df = pd.DataFrame.from_dict(data, columns=['Game_ID','CHAR', 'Port','Frame', 'Pre_frame', 'Post_frame'], orient='index')
    return df

# %%
#TODO Write column tranform as lambda function

# %%
files = listdir('../Data/')
replays_to_df(files[:10])
# Out:
# Failed to parse 20210717T020209.slp
# 20210717T020209.slp is None
#                     Game_ID   CHAR  Port  Frame  \
# 0       20210717T020445.slp    FOX     0      1
# 1       20210717T020445.slp    FOX     0      2
# 2       20210717T020445.slp    FOX     0      3
# 3       20210717T020445.slp    FOX     0      4
# 4       20210717T020445.slp    FOX     0      5
# ...                     ...    ...   ...    ...
# 243153  20210717T025740.slp  MARTH     3   6602
# 243154  20210717T025740.slp  MARTH     3   6603
# 243155  20210717T025740.slp  MARTH     3   6604
# 243156  20210717T025740.slp  MARTH     3   6605
# 243157  20210717T025740.slp  MARTH     3   6606
#
#                                                 Pre_frame  \
# 0       Pre(\n    buttons=Buttons(\n        logical=0b...
# 1       Pre(\n    buttons=Buttons(\n        logical=0b...
# 2       Pre(\n    buttons=Buttons(\n        logical=0b...
# 3       Pre(\n    buttons=Buttons(\n        logical=0b...
# 4       Pre(\n    buttons=Buttons(\n        logical=0b...
# ...                                                   ...
# 243153  Pre(\n    buttons=Buttons(\n        logical=0b...
# 243154  Pre(\n    buttons=Buttons(\n        logical=0b...
# 243155  Pre(\n    buttons=Buttons(\n        logical=0b...
# 243156  Pre(\n    buttons=Buttons(\n        logical=0b...
# 243157  Pre(\n    buttons=Buttons(\n        logical=0b...
#
#                                                Post_frame
# 0       Post(\n    airborne=True,\n    character=1:FOX...
# 1       Post(\n    airborne=True,\n    character=1:FOX...
# 2       Post(\n    airborne=True,\n    character=1:FOX...
# 3       Post(\n    airborne=True,\n    character=1:FOX...
# 4       Post(\n    airborne=True,\n    character=1:FOX...
# ...                                                   ...
# 243153  Post(\n    airborne=True,\n    character=18:MA...
# 243154  Post(\n    airborne=True,\n    character=18:MA...
# 243155  Post(\n    airborne=True,\n    character=18:MA...
# 243156  Post(\n    airborne=True,\n    character=18:MA...
# 243157  Post(\n    airborne=True,\n    character=18:MA...
#
# [243158 rows x 6 columns]
